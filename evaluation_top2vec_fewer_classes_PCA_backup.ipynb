# %%
from trainer import Trainer
import constants


import json
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Out:
# /local/users/unjde

# %%
embeddings = {}
text_labels = []
raw_text_labels_files = []

for file_path in constants.file_paths:
    with open(file_path + "_embeddings_.json", "r") as f:
        embeddings_objects = json.load(f)
        for emb_obj in embeddings_objects:
            embeddings[emb_obj["hash"]] = np.array(emb_obj["embeddings"])

    with open(file_path + "_labeled_fewer_classes.json", "r") as f:
        text_labels_file = json.load(f)
        raw_text_labels_files.append({'ds': file_path, 'raw': text_labels_file})
        for text_hash, doc_info in text_labels_file.items():
            labels_list = [label["system"] for label in doc_info["label"]]
            text_labels.append((text_hash, labels_list))

# %%
# Assuming your initial data processing steps
filtered_embeddings = []
filtered_text_labels = []
doc_values_initial = []
doc_values = []

for item in raw_text_labels_files:
    raw_data = item.get('raw', {})
    for key, value in raw_data.items():
        doc_value = value.get('doc')
        if doc_value:
            doc_values_initial.append(doc_value)

for i, (sample_id, classes) in enumerate(text_labels):
    if classes:
        for label in classes:
            filtered_embeddings.append(embeddings[sample_id])
            filtered_text_labels.append(label)
            doc_values.append(doc_values_initial[i])

# %%
print(len(doc_values))
# Out:
# 6951

# %%
# # Assuming your initial data processing steps
# filtered_embeddings = []
# filtered_text_labels = []

# for sample_id, classes in text_labels:
#     if classes:
#         for label in classes:
#             filtered_embeddings.append(embeddings[sample_id])
#             filtered_text_labels.append(label)

# label_encoder = LabelEncoder()
# X = np.array(filtered_embeddings)
# y = label_encoder.fit_transform(filtered_text_labels)

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# !pip install top2vec nltk
# Out:
# Requirement already satisfied: top2vec in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (1.0.34)
# Requirement already satisfied: nltk in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: numpy>=1.20.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec) (1.26.3)
# Requirement already satisfied: pandas in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec) (1.5.1)
# Requirement already satisfied: gensim>=4.0.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec) (4.3.3)
# Requirement already satisfied: umap-learn>=0.5.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec) (0.5.6)
# Requirement already satisfied: hdbscan>=0.8.27 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec) (0.8.37)
# Requirement already satisfied: wordcloud in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec) (1.9.3)
# Requirement already satisfied: click in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from nltk) (4.66.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from gensim>=4.0.0->top2vec) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from gensim>=4.0.0->top2vec) (7.0.4)
# Requirement already satisfied: cython<3,>=0.27 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from hdbscan>=0.8.27->top2vec) (0.29.37)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from scikit-learn>=1.2.0->top2vec) (3.5.0)
# Requirement already satisfied: numba>=0.51.2 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from umap-learn>=0.5.1->top2vec) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from umap-learn>=0.5.1->top2vec) (0.5.13)
# Requirement already satisfied: python-dateutil>=2.8.2 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pandas->top2vec) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pandas->top2vec) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pandas->top2vec) (2024.1)
# Requirement already satisfied: pillow in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from wordcloud->top2vec) (10.2.0)
# Requirement already satisfied: matplotlib in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from wordcloud->top2vec) (3.9.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn>=0.5.1->top2vec) (0.43.0)
# Requirement already satisfied: six>=1.5 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->top2vec) (1.16.0)
# Requirement already satisfied: wrapt in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from smart-open>=1.8.1->gensim>=4.0.0->top2vec) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec) (3.1.2)

# %%
# !pip install top2vec[sentence_encoders]
# Out:
# Requirement already satisfied: top2vec[sentence_encoders] in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (1.0.34)
# Requirement already satisfied: numpy>=1.20.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (1.26.3)
# Requirement already satisfied: pandas in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (1.5.1)
# Requirement already satisfied: gensim>=4.0.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (4.3.3)
# Requirement already satisfied: umap-learn>=0.5.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (0.5.6)
# Requirement already satisfied: hdbscan>=0.8.27 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (0.8.37)
# Requirement already satisfied: wordcloud in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (1.9.3)
# Requirement already satisfied: tensorflow in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (2.17.0)
# Requirement already satisfied: tensorflow-hub in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (0.16.1)
# Requirement already satisfied: tensorflow-text in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from top2vec[sentence_encoders]) (2.17.0)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from gensim>=4.0.0->top2vec[sentence_encoders]) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from gensim>=4.0.0->top2vec[sentence_encoders]) (7.0.4)
# Requirement already satisfied: cython<3,>=0.27 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from hdbscan>=0.8.27->top2vec[sentence_encoders]) (0.29.37)
# Requirement already satisfied: joblib>=1.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from hdbscan>=0.8.27->top2vec[sentence_encoders]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from scikit-learn>=1.2.0->top2vec[sentence_encoders]) (3.5.0)
# Requirement already satisfied: numba>=0.51.2 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from umap-learn>=0.5.1->top2vec[sentence_encoders]) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from umap-learn>=0.5.1->top2vec[sentence_encoders]) (0.5.13)
# Requirement already satisfied: tqdm in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from umap-learn>=0.5.1->top2vec[sentence_encoders]) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pandas->top2vec[sentence_encoders]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pandas->top2vec[sentence_encoders]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pandas->top2vec[sentence_encoders]) (2024.1)
# Requirement already satisfied: absl-py>=1.0.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (3.3.0)
# Requirement already satisfied: packaging in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (2.32.3)
# Requirement already satisfied: setuptools in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow->top2vec[sentence_encoders]) (0.37.1)
# Requirement already satisfied: tf-keras>=2.14.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorflow-hub->top2vec[sentence_encoders]) (2.17.0)
# Requirement already satisfied: pillow in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from wordcloud->top2vec[sentence_encoders]) (10.2.0)
# Requirement already satisfied: matplotlib in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from wordcloud->top2vec[sentence_encoders]) (3.9.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow->top2vec[sentence_encoders]) (0.43.0)
# Requirement already satisfied: rich in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow->top2vec[sentence_encoders]) (13.7.1)
# Requirement already satisfied: namex in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow->top2vec[sentence_encoders]) (0.0.8)
# Requirement already satisfied: optree in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow->top2vec[sentence_encoders]) (0.12.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn>=0.5.1->top2vec[sentence_encoders]) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow->top2vec[sentence_encoders]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow->top2vec[sentence_encoders]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow->top2vec[sentence_encoders]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow->top2vec[sentence_encoders]) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow->top2vec[sentence_encoders]) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow->top2vec[sentence_encoders]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow->top2vec[sentence_encoders]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec[sentence_encoders]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec[sentence_encoders]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec[sentence_encoders]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec[sentence_encoders]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->wordcloud->top2vec[sentence_encoders]) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->top2vec[sentence_encoders]) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow->top2vec[sentence_encoders]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow->top2vec[sentence_encoders]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->top2vec[sentence_encoders]) (0.1.2)

# %%
from top2vec import Top2Vec
# Out:
# 2024-09-03 21:39:06.045200: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-03 21:39:06.058161: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-03 21:39:06.072463: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-03 21:39:06.076767: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-03 21:39:06.087547: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-03 21:39:07.173749: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import nltk
nltk.download('stopwords')

def remove_stopwords(text):
    stopwords = nltk.corpus.stopwords.words('english')
    text = [word for word in text if word not in stopwords]
    return text
def tok(text):
    import gensim
    text = gensim.utils.simple_preprocess(text)
    text = remove_stopwords(text)
    return text
topic_model = Top2Vec(
    doc_values,
    embedding_model="universal-sentence-encoder",
    speed="deep-learn",
    tokenizer=tok,
    ngram_vocab=True,
    ngram_vocab_args={"connector_words": "phrases.ENGLISH_CONNECTOR_WORDS"},
)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /local/users/unjde/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-09-03 21:39:10,442 - top2vec - INFO - Pre-processing documents for training
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 2024-09-03 21:39:14,977 - top2vec - INFO - Downloading universal-sentence-encoder model
# 2024-09-03 21:39:15.191470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22462 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1b:00.0, compute capability: 8.6
# 2024-09-03 21:39:15.192103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22462 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6
# 2024-09-03 21:39:19,182 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2024-09-03 21:39:32,266 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2024-09-03 21:39:53,336 - top2vec - INFO - Finding dense areas of documents
# INFO:top2vec:Finding dense areas of documents
# 2024-09-03 21:39:53,481 - top2vec - INFO - Finding topics
# INFO:top2vec:Finding topics

# %%
model_path = 'model/topic2vec'

topic_model = Top2Vec.load(model_path)
topic_model.save(model_path)

# %%
topic_model.get_num_topics()
# Out:
# 37

# %%
topic_words, word_scores, topic_nums = topic_model.get_topics(37)

# %%
topic_words[2]
# Out:
# array(['spokesman said', 'police spokesman', 'police chief', 'according',
#        'told reporters', 'police said', 'office said', 'spokesman',
#        'safety', 'said think', 'security chief', 'officials said', 'said',
#        'company said', 'decision', 'spokeswoman said', 'said filed',
#        'security officials', 'newspaper said', 'inc said', 'told reuters',
#        'gov', 'said monday', 'maintenance', 'article protected',
#        'told news', 'surgical management', 'regulation', 'said statement',
#        'said company', 'corp said', 'agreement', 'security', 'said know',
#        'management', 'secretary', 'another', 'official said',
#        'xinhua news', 'rrb said', 'attorney general', 'supreme court',
#        'operative management', 'luciferase reporter', 'quoted saying',
#        'one case', 'secretary state', 'jeff wilson', 'policy',
#        'regulatory'], dtype='<U27')

# %%
# topic_words, word_scores, topic_nums = topic_model.get_topics(37)
# for topic in topic_nums:
#     topic_model.generate_topic_wordcloud(topic)

# %%
document_topics, scores, words, topic_word_emb = topic_model.get_documents_topics(doc_ids=list(range(len(doc_values))))
assert len(doc_values) == len(document_topics)
print(doc_values[2383])
print(document_topics[2383])
print(words[2383])
print(scores[2383])
# Out:
# CRICKET - SRI LANKA BEAT AUSTRALIA BY FOUR WICKETS .  COLOMBO 1996-08-30  Sri Lanka beat Australia by four wickets in the third match of the Singer World Series one-day ( 50 overs ) cricket tournament on Friday .  Scores : Australia 228-9 in 50 overs , Sri Lanka 232-6 in 45.5 overs .
# 1
# ['told reuters' 'stock market' 'traders said' 'trader said'
#  'stock exchange' 'insider trading' 'securities exchange' 'dow jones'
#  'reuters verified' 'brokers said' 'reuters' 'analysts said' 'traders'
#  'earnings' 'securities' 'profit taking' 'expected rise' 'shares'
#  'investors' 'stock' 'economic losses' 'common stock' 'goldman sachs'
#  'quantitative structure' 'central bank' 'shares traded'
#  'trading thursday' 'xinhua news' 'resulted lower' 'analysts' 'loss yen'
#  'holding company' 'told news' 'wall street' 'quantitative analysis'
#  'percent rise' 'million shares' 'bond market' 'us dollar' 'one trader'
#  'preferred shares' 'loss mln' 'economic' 'earnings per' 'trading'
#  'common shares' 'quantitative' 'subordinated debentures' 'investment'
#  'quantitative fetal']
# 0.5339232

# %%
topic_model.word_vectors[topic_model.word_indexes['searched pubmed']]
# Out:
# array([ 6.37386460e-04,  2.43113153e-02,  5.22076972e-02, -2.42720600e-02,
#        -7.46904165e-02, -4.64939550e-02,  4.08156998e-02, -3.20593230e-02,
#         7.07654580e-02,  2.99914293e-02,  8.36167485e-02,  3.25061269e-02,
#         4.34492715e-02,  7.49886259e-02, -2.12146528e-02, -1.05210189e-02,
#        -9.12138522e-02,  3.44455970e-04,  5.66623695e-02, -6.79576844e-02,
#        -8.06702450e-02,  1.01255877e-02, -4.47166674e-02,  6.84815496e-02,
#         3.30226012e-02,  5.94569743e-02,  1.02855666e-02,  2.81878840e-02,
#        -1.94824580e-02,  4.38535847e-02, -3.60790379e-02,  9.13784131e-02,
#         4.82433252e-02, -6.45298362e-02, -6.08761609e-02, -6.33781254e-02,
#        -8.31005499e-02, -5.66018280e-03, -2.64994949e-02,  1.31892702e-02,
#        -4.87522110e-02,  1.10884011e-03, -3.65621559e-02, -5.00846002e-03,
#         7.35711157e-02,  5.51315546e-02,  4.39103879e-02,  9.66638047e-03,
#         2.85654585e-03,  1.90407634e-02, -8.63206685e-02,  6.10364452e-02,
#         3.38242166e-02,  5.74307144e-02, -4.02831212e-02, -1.55185331e-02,
#         6.61362857e-02,  6.78536147e-02,  7.88971558e-02,  5.34289926e-02,
#        -5.31280041e-02,  4.66791913e-02,  1.94768067e-02, -3.56337652e-02,
#         2.42614169e-02, -7.23203197e-02, -8.44781250e-02,  2.70695463e-02,
#         3.52016129e-02, -5.70428558e-02,  1.09577812e-02,  9.78180859e-03,
#        -5.29222302e-02, -1.20479763e-02, -1.99239980e-02,  5.05264103e-02,
#         8.19485039e-02,  1.31647266e-03, -2.20225882e-02, -1.19157713e-02,
#        -7.46467151e-03,  1.63304266e-02,  1.07974550e-02,  2.55240463e-02,
#        -3.77350971e-02,  5.86705506e-02,  1.13635221e-02, -3.36112306e-02,
#        -5.32942973e-02, -5.76403663e-02,  6.66308496e-03, -4.74708602e-02,
#        -2.67921444e-02, -2.89669987e-02, -4.09476534e-02,  7.78418779e-02,
#         4.21505533e-02, -3.53771225e-02,  6.88783079e-02,  5.87371252e-02,
#        -2.00327486e-02, -8.63152836e-03, -3.85100767e-02,  5.09537347e-02,
#         1.66503582e-02,  2.57457998e-02,  6.00443147e-02,  6.10841140e-02,
#        -1.71096828e-02, -7.92999007e-03,  6.75964281e-02,  2.86580157e-02,
#        -3.29516195e-02,  2.65715681e-02, -7.32472017e-02,  2.18181852e-02,
#        -2.45644879e-02, -2.80031306e-03,  4.29634303e-02, -6.91075204e-03,
#        -4.94179912e-02,  5.28064370e-02,  6.15359582e-02, -6.95715323e-02,
#         4.84896898e-02,  1.57539696e-02, -6.43472299e-02,  4.21289392e-02,
#        -7.24388808e-02, -3.77721377e-02, -1.00161775e-03,  9.28589180e-02,
#         5.49751408e-02,  6.55186102e-02, -1.26177873e-02,  6.31719008e-02,
#         5.57714924e-02,  6.14689663e-02,  4.61729839e-02, -3.34660485e-02,
#        -8.68592318e-03, -4.03636917e-02, -4.50983681e-02,  5.45215905e-02,
#        -3.51930633e-02, -2.31885426e-02,  2.28999276e-02, -3.33235748e-02,
#        -8.73909518e-03,  1.81134418e-02, -5.57175502e-02,  3.16188410e-02,
#        -7.19268024e-02, -1.91366412e-02,  9.20420885e-02, -2.18524281e-02,
#        -2.96268128e-02,  4.19169590e-02, -4.98073399e-02, -2.14332417e-02,
#        -3.26599064e-03, -1.30537776e-02,  4.96678576e-02,  5.44107333e-02,
#        -6.04459755e-02,  2.25962773e-02, -6.14327788e-02,  1.04597015e-02,
#        -9.26435590e-02,  1.61449946e-02, -1.68588832e-02, -7.03199133e-02,
#        -3.62276041e-05, -3.48377787e-02,  4.37982902e-02,  4.11205702e-02,
#         2.24880595e-02,  5.72550260e-02, -1.29238954e-02,  1.00885015e-02,
#         1.36729646e-02, -7.04129189e-02, -5.06420806e-02,  5.22490852e-02,
#         7.50728622e-02, -1.37559343e-02, -2.58498043e-02,  5.69680929e-02,
#        -2.71475483e-02,  2.41022334e-02,  4.11208831e-02,  2.91012209e-02,
#        -2.12871426e-04, -1.95972342e-02,  6.65249005e-02, -4.76241484e-03,
#         1.34466225e-02, -6.92116395e-02,  1.88536625e-02, -4.05465625e-02,
#        -4.17646468e-02, -7.88754225e-02,  2.19210912e-03, -1.91211440e-02,
#        -9.51195322e-03,  3.79814953e-03,  7.65076354e-02, -4.55790237e-02,
#        -4.18673754e-02,  2.39863945e-03, -9.01474655e-02, -3.65366489e-02,
#        -4.20817509e-02,  4.07092050e-02, -3.71317305e-02, -2.32926086e-02,
#        -4.76980954e-03,  3.62042859e-02,  4.39881794e-02, -4.02679816e-02,
#        -3.00362855e-02,  1.06472634e-02,  1.65052712e-02,  2.92488979e-03,
#         3.75063159e-02, -5.74449264e-02, -3.26205641e-02,  3.85532454e-02,
#         6.03107444e-04, -1.08094178e-02,  2.64383908e-02, -6.46222383e-02,
#         4.52336716e-03,  8.74588266e-02,  3.17873247e-02, -3.31084169e-02,
#         7.46959969e-02, -1.17690163e-03,  3.08011584e-02, -1.01971067e-02,
#         2.75467150e-02,  3.88574600e-02,  5.42627946e-02, -3.21091637e-02,
#        -1.06797116e-02, -3.93379070e-02, -2.27493271e-02, -3.99667285e-02,
#         3.82773466e-02, -8.60038772e-02,  6.15944713e-03, -6.90209791e-02,
#        -6.54750615e-02,  3.59326489e-02,  1.89032158e-04,  5.06888367e-02,
#         5.29834479e-02, -3.06370836e-02, -5.90072619e-03,  3.08697689e-02,
#         2.33249720e-02, -3.38480249e-02,  8.80492013e-03, -1.85526107e-02,
#        -6.33803196e-03,  4.02182378e-02, -7.87079625e-05,  8.02285150e-02,
#        -5.24637625e-02,  3.34147550e-02,  1.95856728e-02, -7.83115774e-02,
#        -3.04861516e-02, -6.95048943e-02,  5.00913598e-02,  4.02607583e-03,
#        -1.63462404e-02, -1.71076469e-02,  6.15141653e-02,  1.19027427e-04,
#        -4.66098450e-02, -9.85793583e-03, -1.33545743e-02, -3.17466483e-02,
#         2.28814930e-02, -3.58046331e-02,  3.45749371e-02, -2.62225680e-02,
#        -5.14688939e-02, -6.69203848e-02,  3.43563668e-02, -5.05145863e-02,
#         8.21333528e-02, -6.97445571e-02,  7.50879347e-02, -6.09990396e-02,
#        -3.28276567e-02,  3.02550439e-02, -2.97176577e-02,  5.67532182e-02,
#        -1.01752253e-02,  2.83071119e-02,  4.22843136e-02, -4.07013260e-02,
#        -2.65662540e-02, -2.67855171e-02, -6.47549983e-03, -2.11112034e-02,
#        -2.90906280e-02, -1.31241521e-02,  8.00698530e-03, -4.84163202e-02,
#         2.17967741e-02, -1.54904360e-02,  8.41545835e-02, -1.85571816e-02,
#        -5.84215857e-02, -5.46732498e-03,  2.27939012e-03, -4.98278923e-02,
#        -5.13930321e-02, -6.63961172e-02, -4.54828925e-02,  4.41667475e-02,
#        -7.99197406e-02, -3.80306714e-03,  5.20794652e-02, -4.82007787e-02,
#         5.32053858e-02, -1.45414984e-02, -4.84740920e-02, -5.79908751e-02,
#         2.84151379e-02,  6.90499097e-02,  5.00911847e-02, -1.13863009e-03,
#        -6.42586052e-02, -7.17337430e-03, -5.27309370e-04, -6.03303015e-02,
#        -4.23290022e-02, -5.27602248e-03,  4.02559340e-02, -8.42369627e-04,
#        -6.69888332e-02, -7.63349384e-02,  4.97143604e-02,  6.27663806e-02,
#        -5.67666255e-02, -1.00211322e-03, -1.40780322e-02,  3.07558179e-02,
#         2.14820914e-02,  3.96286789e-03,  4.20943424e-02, -2.30853707e-02,
#        -8.45812410e-02, -6.11334480e-03,  4.82338481e-02,  4.72087115e-02,
#        -1.14480518e-02, -2.11939355e-03,  2.82455254e-02,  2.55069882e-02,
#        -3.11594866e-02, -4.09540385e-02,  8.36174712e-02,  6.88340664e-02,
#        -2.19942853e-02, -2.02821866e-02, -5.96390925e-02, -3.14923115e-02,
#         1.13846175e-02, -8.78153592e-02,  3.85906622e-02,  1.59856654e-03,
#         2.33697854e-02, -4.29715887e-02, -5.62741905e-02, -3.57103795e-02,
#        -4.69641984e-02, -2.69105006e-02, -2.23347615e-03,  6.44702406e-04,
#         2.11974476e-02, -6.25226349e-02,  8.61611813e-02,  9.17058811e-03,
#         3.44016366e-02, -6.29453510e-02,  4.65499908e-02,  2.73847412e-02,
#         2.71805525e-02, -5.94216809e-02, -6.43046724e-06,  4.74631041e-03,
#        -1.25690894e-02, -8.60670060e-02, -5.23836538e-02, -8.58021677e-02,
#         2.60561239e-02, -1.57981627e-02,  1.92106646e-02,  4.56778556e-02,
#         8.49436130e-03, -4.44251336e-02, -3.54081728e-02, -8.56549758e-03,
#        -6.89465404e-02,  3.15612927e-02,  2.91886684e-02,  1.84197128e-02,
#         4.77653407e-02, -5.11300303e-02, -3.72220948e-02, -4.82372195e-02,
#         3.71491238e-02,  3.24955918e-02,  4.70280200e-02, -4.30541597e-02,
#        -4.16027084e-02, -6.51490763e-02,  3.30890082e-02,  1.18801557e-02,
#         1.45097328e-02, -1.28773954e-02,  8.49452540e-02,  5.55078313e-02,
#         2.51128916e-02,  2.21524201e-03, -1.34561555e-02, -3.45430593e-03,
#        -7.08830059e-02, -3.25316340e-02, -4.02413262e-03, -2.70378552e-02,
#         6.58401400e-02, -4.37500924e-02,  7.18932524e-02,  5.94687648e-03,
#        -6.38295934e-02, -5.30039445e-02, -6.59098029e-02,  2.53466275e-02,
#         1.72691606e-02, -5.37771359e-02,  3.51792239e-02,  1.78486407e-02,
#         4.10382496e-03,  5.16041443e-02,  4.97823358e-02, -2.67714094e-02,
#        -9.39335395e-03,  2.79332008e-02,  1.67890359e-02,  6.89048171e-02,
#        -6.20646104e-02, -5.77404201e-02, -7.86877424e-02, -3.51896994e-02,
#         1.46235595e-03, -2.08436847e-02,  4.76018116e-02, -6.83577731e-02,
#         3.12976949e-02, -3.40802372e-02,  1.10121891e-02, -1.62392128e-02,
#         2.91146375e-02,  3.21901664e-02,  5.55363037e-02, -3.02962661e-02,
#        -3.79999503e-02,  4.52011116e-02, -5.19233346e-02,  4.62160856e-02,
#        -4.28142548e-02, -1.91945825e-02,  1.21917576e-03, -1.45954825e-02,
#         3.49924043e-02,  3.80449370e-02, -6.12451322e-02, -3.32259499e-02,
#         2.01977063e-02, -3.94728594e-02, -2.36423928e-02, -4.39567901e-02,
#        -1.36129623e-02, -4.20213379e-02, -4.93925028e-02,  9.92114842e-03,
#         2.35294960e-02, -3.37928049e-02,  1.58385281e-02, -4.77805398e-02,
#        -6.79924116e-02, -8.65323022e-02, -2.19634287e-02, -9.14539397e-03,
#         8.66673980e-03, -3.34297046e-02, -1.16236219e-02, -8.84000212e-02,
#         5.57019077e-02, -9.28696543e-02,  3.15544568e-02, -3.91578674e-02,
#         4.80856635e-02,  3.76189947e-02, -5.51003590e-02, -3.21997516e-02],
#       dtype=float32)

# %%
from sklearn.preprocessing import OneHotEncoder

one_hot_encoder = OneHotEncoder()
document_topics_one_hot = one_hot_encoder.fit_transform(np.reshape(document_topics, (-1,1)))

# %%
document_topics_one_hot
# Out:
# <6951x37 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6951 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse import csr_matrix

sparse_matrix = csr_matrix(document_topics_one_hot).toarray()

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(filtered_text_labels)

X_emb_only = np.array(filtered_embeddings)

X_topics = np.array(sparse_matrix)

pca = PCA(n_components=100)

filtered_embeddings_pca = pca.fit_transform(filtered_embeddings)

X_combined_one_hot = np.hstack((X_topics, filtered_embeddings))

X_combined_one_hot_pca = np.hstack((X_topics, filtered_embeddings_pca))


X_combined_top_word_emb = np.hstack((topic_word_emb, filtered_embeddings))
X_combined_top_word_emb_pca = np.hstack((topic_word_emb, filtered_embeddings_pca))

X_topic_word_emb = topic_word_emb

# %%
document_topics = [[e] for e in document_topics]
print(len(document_topics))
len(X_topics)
# Out:
# 6951
# 6951

# %%
X_combined_topic_num_PCA_emb = np.hstack((document_topics, filtered_embeddings))

# %%
assert len(filtered_text_labels) == len(sparse_matrix)

# %%
def evaluate(X, y):
    result = {}
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    trainer = Trainer()
    trainer.train(X_train, y_train)

    predictions = trainer.predict(X_test)


    class_names = label_encoder.classes_

    for name, preds in predictions.items():
        accuracy, f1, recall = trainer.evaluate(y_test, preds)
        result[name] = {'accuracy': accuracy}
        print(f"{name} accuracy: {accuracy}, f1 score: {f1}, recall: {recall}")

    for name, preds in predictions.items():
        cm = confusion_matrix(y_test, preds)

        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=class_names, yticklabels=class_names)
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title(f'Confusion Matrix - {name}')
        plt.show()

    print(trainer.get_best_params())
    return result

# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from dtreeviz) (2.2.2)
# Requirement already satisfied: numpy in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from dtreeviz) (1.26.3)
# Requirement already satisfied: scikit-learn in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from dtreeviz) (1.5.1)
# Requirement already satisfied: matplotlib in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from dtreeviz) (3.9.1)
# Requirement already satisfied: colour in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from dtreeviz) (8.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->dtreeviz) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->dtreeviz) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->dtreeviz) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->dtreeviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->dtreeviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from matplotlib->dtreeviz) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pandas->dtreeviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pandas->dtreeviz) (2024.1)
# Requirement already satisfied: iniconfig in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pytest->dtreeviz) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from pytest->dtreeviz) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, f1_score, recall_score

X_train, X_test, y_train, y_test = train_test_split(X_topics, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier(n_estimators=10, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')

print(f"Random Forest accuracy: {accuracy}, f1 score: {f1}, recall: {recall}")


#feature_names = [f'Feature {i}' for i in range(X_combined_topic_num_PCA_emb.shape[1])]

plt.figure(figsize=(20, 10))
plot_tree(rf.estimators_[0],class_names=rf.classes_.astype(str), filled=True)
plt.savefig('out.pdf')
plt.show()
# Out:
# Random Forest accuracy: 0.41946308724832215, f1 score: 0.31369943614803536, recall: 0.41946308724832215

# %%
# Extracting model names
models = list(results_dict['docEmbOnly'].keys())

# Extracting accuracies for each method
accuracy_doc_emb = [results_dict['docEmbOnly'][model]['accuracy'] for model in models]
accuracy_one_hot = [results_dict['combOneHot'][model]['accuracy'] for model in models]
accuracy_only_features = [results_dict['combTopcWord'][model]['accuracy'] for model in models]
accuracy_pca_one_hot_doc_emb = [results_dict['oneHotPCA'][model]['accuracy'] for model in models]
accuracy_pca_topic_emb = [results_dict['topicPCA'][model]['accuracy'] for model in models]
accuracy_one_hot_only = [results_dict['oneHotOnly'][model]['accuracy'] for model in models]

# Plotting Accuracy
plt.figure(figsize=(14, 8))
plt.plot(models, accuracy_doc_emb, marker='o', color='b', linestyle='-', label='Document embedding vector only')
plt.plot(models, accuracy_one_hot, marker='s', color='r', linestyle='--', label='One-hot encoded topics + Doc emb')
plt.plot(models, accuracy_only_features, marker='^', color='g', linestyle='-.', label='Only features')
plt.plot(models, accuracy_pca_one_hot_doc_emb, marker='D', color='m', linestyle=':', label='PCA one hot + doc emb')
plt.plot(models, accuracy_pca_topic_emb, marker='x', color='c', linestyle='-', label='PCA + topic emb')
plt.plot(models, accuracy_one_hot_only, marker='*', color='orange', linestyle='-', label='One-hot encoded only')
plt.xticks(rotation=45)
plt.title('Accuracy of Models')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.show()

# %%
results_dict = {}

# %%
print("----------------- evaluate: doc emb only ---------------------")
results_dict['docEmbOnly'] = evaluate(X_emb_only, y)
# Out:
# ----------------- evaluate: doc emb only ---------------------
# Training dummy_mf...
# Training dummy_pr...
# Training dummy_st...
# Training dummy_un...
# Training random_forest...
# Training svm...
# Training knn...
# Training mlp...
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# dummy_mf accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_pr accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_st accuracy: 0.1601150527325024, f1 score: 0.16074395932956, recall: 0.1601150527325024
# dummy_un accuracy: 0.1342281879194631, f1 score: 0.14197157415261302, recall: 0.1342281879194631
# random_forest accuracy: 0.45158197507190795, f1 score: 0.41085479560580307, recall: 0.45158197507190795
# svm accuracy: 0.48465963566634707, f1 score: 0.4465215348324991, recall: 0.48465963566634707
# knn accuracy: 0.4549376797698945, f1 score: 0.4403582561721649, recall: 0.4549376797698945
# mlp accuracy: 0.4813039309683605, f1 score: 0.45981566326341394, recall: 0.4813039309683605
# {'dummy_mf': {}, 'dummy_pr': {}, 'dummy_st': {}, 'dummy_un': {}, 'random_forest': {'max_depth': None, 'n_estimators': 200}, 'svm': {'C': 0.1, 'kernel': 'linear'}, 'knn': {'n_neighbors': 7, 'p': 1}, 'mlp': {'activation': 'relu', 'hidden_layer_sizes': (50,), 'solver': 'sgd'}}

# %%
results_dict
# Out:
# {'docEmbOnly': {'dummy_mf': {'accuracy': 0.23537871524448706},
#   'dummy_pr': {'accuracy': 0.23537871524448706},
#   'dummy_st': {'accuracy': 0.1601150527325024},
#   'dummy_un': {'accuracy': 0.1342281879194631},
#   'random_forest': {'accuracy': 0.45158197507190795},
#   'svm': {'accuracy': 0.48465963566634707},
#   'knn': {'accuracy': 0.4549376797698945},
#   'mlp': {'accuracy': 0.4813039309683605}}}

# %%
print("----------------- evaluate: combined one one encoding (noisy) ---------------------")
results_dict['combOneHot'] = evaluate(X_combined_one_hot, y)
print("----------------- evaluate: combined topic word emb ---------------------")
results_dict['combTopcWord'] = evaluate(X_combined_top_word_emb, y)
# Out:
# ----------------- evaluate: combined one one encoding (noisy) ---------------------
# Training dummy_mf...
# Training dummy_pr...
# Training dummy_st...
# Training dummy_un...
# Training random_forest...
# Training svm...
# Training knn...
# Training mlp...
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# dummy_mf accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_pr accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_st accuracy: 0.188398849472675, f1 score: 0.18890781601063328, recall: 0.188398849472675
# dummy_un accuracy: 0.13902205177372962, f1 score: 0.1483726382756321, recall: 0.13902205177372962
# random_forest accuracy: 0.4434324065196548, f1 score: 0.3995794694295481, recall: 0.4434324065196548
# svm accuracy: 0.48370086289549374, f1 score: 0.446211080397853, recall: 0.48370086289549374
# knn accuracy: 0.45445829338446786, f1 score: 0.44166202450820524, recall: 0.45445829338446786
# mlp accuracy: 0.48465963566634707, f1 score: 0.4651587911818561, recall: 0.48465963566634707
# {'dummy_mf': {}, 'dummy_pr': {}, 'dummy_st': {}, 'dummy_un': {}, 'random_forest': {'max_depth': 30, 'n_estimators': 200}, 'svm': {'C': 0.1, 'kernel': 'linear'}, 'knn': {'n_neighbors': 7, 'p': 1}, 'mlp': {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'solver': 'sgd'}}
# ----------------- evaluate: combined topic word emb ---------------------
# Training dummy_mf...
# Training dummy_pr...
# Training dummy_st...
# Training dummy_un...
# Training random_forest...
# Training svm...
# Training knn...
# Training mlp...
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# dummy_mf accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_pr accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_st accuracy: 0.18120805369127516, f1 score: 0.18069479481511413, recall: 0.18120805369127516
# dummy_un accuracy: 0.1404602109300096, f1 score: 0.148191527532143, recall: 0.1404602109300096
# random_forest accuracy: 0.4482262703739214, f1 score: 0.38563784111651767, recall: 0.4482262703739214
# svm accuracy: 0.48178331735378715, f1 score: 0.44328012132170524, recall: 0.48178331735378715
# knn accuracy: 0.4458293384467881, f1 score: 0.43115121131167855, recall: 0.4458293384467881
# mlp accuracy: 0.48465963566634707, f1 score: 0.46487879373392743, recall: 0.48465963566634707
# {'dummy_mf': {}, 'dummy_pr': {}, 'dummy_st': {}, 'dummy_un': {}, 'random_forest': {'max_depth': 10, 'n_estimators': 200}, 'svm': {'C': 0.1, 'kernel': 'linear'}, 'knn': {'n_neighbors': 7, 'p': 1}, 'mlp': {'activation': 'relu', 'hidden_layer_sizes': (50,), 'solver': 'sgd'}}

# %%
print("----------------- evaluate: combined one one encoding (noisy) (PCA) ---------------------")
results_dict['oneHotPCA'] = evaluate(X_combined_one_hot_pca, y)
print("----------------- evaluate: combined topic word emb (PCA) ---------------------")
results_dict['topicPCA'] = evaluate(X_combined_top_word_emb_pca, y)
# Out:
# ----------------- evaluate: combined one one encoding (noisy) (PCA) ---------------------
# Training dummy_mf...
# Training dummy_pr...
# Training dummy_st...
# Training dummy_un...
# Training random_forest...
# Training svm...
# Training knn...
# Training mlp...
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# dummy_mf accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_pr accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_st accuracy: 0.1860019175455417, f1 score: 0.18654106677913374, recall: 0.1860019175455417
# dummy_un accuracy: 0.13998082454458294, f1 score: 0.14896054009753448, recall: 0.13998082454458294
# random_forest accuracy: 0.4534995206136146, f1 score: 0.4096291953336435, recall: 0.4534995206136146
# svm accuracy: 0.48370086289549374, f1 score: 0.446211080397853, recall: 0.48370086289549374
# knn accuracy: 0.4549376797698945, f1 score: 0.4421578302606195, recall: 0.4549376797698945
# mlp accuracy: 0.4851390220517737, f1 score: 0.46427523065372805, recall: 0.4851390220517737
# {'dummy_mf': {}, 'dummy_pr': {}, 'dummy_st': {}, 'dummy_un': {}, 'random_forest': {'max_depth': 20, 'n_estimators': 200}, 'svm': {'C': 0.1, 'kernel': 'linear'}, 'knn': {'n_neighbors': 7, 'p': 1}, 'mlp': {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'solver': 'sgd'}}
# ----------------- evaluate: combined topic word emb (PCA) ---------------------
# Training dummy_mf...
# Training dummy_pr...
# Training dummy_st...
# Training dummy_un...
# Training random_forest...
# Training svm...
# Training knn...
# Training mlp...
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /local/users/unjde/analysis/.conda/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# dummy_mf accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_pr accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_st accuracy: 0.1840843720038351, f1 score: 0.1848858839492475, recall: 0.1840843720038351
# dummy_un accuracy: 0.137104506232023, f1 score: 0.14651359013790277, recall: 0.137104506232023
# random_forest accuracy: 0.45445829338446786, f1 score: 0.4116046305433526, recall: 0.45445829338446786
# svm accuracy: 0.48178331735378715, f1 score: 0.44328012132170524, recall: 0.48178331735378715
# knn accuracy: 0.4458293384467881, f1 score: 0.43115121131167855, recall: 0.4458293384467881
# mlp accuracy: 0.4856184084372004, f1 score: 0.46847218795094514, recall: 0.4856184084372004
# {'dummy_mf': {}, 'dummy_pr': {}, 'dummy_st': {}, 'dummy_un': {}, 'random_forest': {'max_depth': None, 'n_estimators': 200}, 'svm': {'C': 0.1, 'kernel': 'linear'}, 'knn': {'n_neighbors': 7, 'p': 1}, 'mlp': {'activation': 'tanh', 'hidden_layer_sizes': (50, 50), 'solver': 'sgd'}}

# %%
print("----------------- evaluate:  one encoding (noisy) ---------------------")
results_dict['oneHotOnly'] = evaluate(X_topics, y)
# Out:
# ----------------- evaluate:  one encoding (noisy) ---------------------
# Training dummy_mf...
# Training dummy_pr...
# Training dummy_st...
# Training dummy_un...
# Training random_forest...
# Training svm...
# Training knn...
# Training mlp...
# dummy_mf accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_pr accuracy: 0.23537871524448706, f1 score: 0.08969417864574555, recall: 0.23537871524448706
# dummy_st accuracy: 0.1673058485139022, f1 score: 0.16815210756554946, recall: 0.1673058485139022
# dummy_un accuracy: 0.13662511984659637, f1 score: 0.14513534615022652, recall: 0.13662511984659637
# random_forest accuracy: 0.4204218600191755, f1 score: 0.3087483868266939, recall: 0.4204218600191755
# svm accuracy: 0.4199424736337488, f1 score: 0.2766180841352921, recall: 0.4199424736337488
# knn accuracy: 0.412751677852349, f1 score: 0.2884635973439487, recall: 0.412751677852349
# mlp accuracy: 0.4146692233940556, f1 score: 0.30905255170902957, recall: 0.4146692233940556
# {'dummy_mf': {}, 'dummy_pr': {}, 'dummy_st': {}, 'dummy_un': {}, 'random_forest': {'max_depth': 30, 'n_estimators': 50}, 'svm': {'C': 0.1, 'kernel': 'linear'}, 'knn': {'n_neighbors': 7, 'p': 1}, 'mlp': {'activation': 'relu', 'hidden_layer_sizes': (100,), 'solver': 'adam'}}

# %%
results_dict
# Out:
# {'docEmbOnly': {'dummy_mf': {'accuracy': 0.23537871524448706},
#   'dummy_pr': {'accuracy': 0.23537871524448706},
#   'dummy_st': {'accuracy': 0.1601150527325024},
#   'dummy_un': {'accuracy': 0.1342281879194631},
#   'random_forest': {'accuracy': 0.45158197507190795},
#   'svm': {'accuracy': 0.48465963566634707},
#   'knn': {'accuracy': 0.4549376797698945},
#   'mlp': {'accuracy': 0.4813039309683605}},
#  'combOneHot': {'dummy_mf': {'accuracy': 0.23537871524448706},
#   'dummy_pr': {'accuracy': 0.23537871524448706},
#   'dummy_st': {'accuracy': 0.188398849472675},
#   'dummy_un': {'accuracy': 0.13902205177372962},
#   'random_forest': {'accuracy': 0.4434324065196548},
#   'svm': {'accuracy': 0.48370086289549374},
#   'knn': {'accuracy': 0.45445829338446786},
#   'mlp': {'accuracy': 0.48465963566634707}},
#  'combTopcWord': {'dummy_mf': {'accuracy': 0.23537871524448706},
#   'dummy_pr': {'accuracy': 0.23537871524448706},
#   'dummy_st': {'accuracy': 0.18120805369127516},
#   'dummy_un': {'accuracy': 0.1404602109300096},
#   'random_forest': {'accuracy': 0.4482262703739214},
#   'svm': {'accuracy': 0.48178331735378715},
#   'knn': {'accuracy': 0.4458293384467881},
#   'mlp': {'accuracy': 0.48465963566634707}},
#  'oneHotPCA': {'dummy_mf': {'accuracy': 0.23537871524448706},
#   'dummy_pr': {'accuracy': 0.23537871524448706},
#   'dummy_st': {'accuracy': 0.1860019175455417},
#   'dummy_un': {'accuracy': 0.13998082454458294},
#   'random_forest': {'accuracy': 0.4534995206136146},
#   'svm': {'accuracy': 0.48370086289549374},
#   'knn': {'accuracy': 0.4549376797698945},
#   'mlp': {'accuracy': 0.4851390220517737}},
#  'topicPCA': {'dummy_mf': {'accuracy': 0.23537871524448706},
#   'dummy_pr': {'accuracy': 0.23537871524448706},
#   'dummy_st': {'accuracy': 0.1840843720038351},
#   'dummy_un': {'accuracy': 0.137104506232023},
#   'random_forest': {'accuracy': 0.45445829338446786},
#   'svm': {'accuracy': 0.48178331735378715},
#   'knn': {'accuracy': 0.4458293384467881},
#   'mlp': {'accuracy': 0.4856184084372004}},
#  'oneHotOnly': {'dummy_mf': {'accuracy': 0.23537871524448706},
#   'dummy_pr': {'accuracy': 0.23537871524448706},
#   'dummy_st': {'accuracy': 0.1673058485139022},
#   'dummy_un': {'accuracy': 0.13662511984659637},
#   'random_forest': {'accuracy': 0.4204218600191755},
#   'svm': {'accuracy': 0.4199424736337488},
#   'knn': {'accuracy': 0.412751677852349},
#   'mlp': {'accuracy': 0.4146692233940556}}}

# %%
def get_text_and_ds_by_hash(hash: str):
    for raw_f in raw_text_labels_files:
        ds, raw_f = raw_f.values()
        for text_hash, doc_info in raw_f.items():
            if text_hash == hash:
                return doc_info, ds

# %%
# !pip install rdflib
# Out:
# Collecting rdflib
#   Downloading rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from rdflib) (3.1.2)
# Requirement already satisfied: six in /local/users/unjde/analysis/.conda/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
# Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 20.9 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 26.9 MB/s eta 0:00:00
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-7.0.0

# %%
from metric_calculator import MetricCalculator
from nif_loader import NifLoader
from json_loader import JsonLoader
from helpers import hashStringSha256

# %%
mc = MetricCalculator()

# %%
base_path = '/work/combining-linking-techniques/clit_backend/.clit_root/default/resources/data/experiment_results/MDOnly/'

sample_id, classes = text_labels[2438]
embedding = embeddings[sample_id]
doc_info, ds = get_text_and_ds_by_hash(sample_id)
print(f'The sample hash/id: {sample_id}')
#print(f'This id corresponds to : {doc_info['doc']}')
# Out:
# The sample hash/id: 6b6f6a6625a1cc07af9b713c1594ed7f48424e3b3817707f2cebb6610df3f986

# %%
# predict
prediction = trainer.predict([embedding])
classes_pred_by_name = list([class_names[v][0] for _, v in prediction.items()])[0]
print(f'Our models predicted: {classes_pred_by_name}')
# truth
print(f'True class is: {classes[0]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # predict
# ----> 2 prediction = trainer.predict([embedding])
#       3 classes_pred_by_name = list([class_names[v][0] for _, v in prediction.items()])[0]
#       4 print(f'Our models predicted: {classes_pred_by_name}')
#
# NameError: name 'trainer' is not defined

# %%
# following a wrong class
wrong_json_path = constants.HOME + base_path + ds.split('/')[-2].replace('.json', '') + f'/REL MD (.properties)/{sample_id}.json'
wrong_systems_mentions = mc.getSystemMentions(wrong_json_path)
print(f'Following a wrong class, we get the following mentions: {wrong_systems_mentions}')
# Out:
# Following a wrong class, we get the following mentions: {'127_DM', '641_MRI', '1806_MRI', '865_MRI', '2141_MRI', '2247_MRI', '2301_MRI', '1042_MRI', '1530_A1c', '1762_MRI', '1252_Staten Island University Hospital', '2556_MRI', '1500_DM'}

# %%
# following preds
pred_json_path = constants.HOME + base_path + ds.split('/')[-2].replace('.json', '') + f'/{classes_pred_by_name}/{sample_id}.json'
predicted_systems_mentions = mc.getSystemMentions(pred_json_path)
print(f'Following our models suggestions, we get the following mentions: {predicted_systems_mentions}')
# Out:
# Following our models suggestions, we get the following mentions: {'2385_diabetic', '2385_diabetic foot', '1380_hallux', '756_hypothesis', '1203_retrospective cohort', '746_foot', '1252_Staten Island University Hospital', '2471_mortality rate', '377_risk', '1930_cardiovascular disease', '2301_MRI', '1638_radiographic', '1388_amputation', '1831_amputation', '666_amputation', '252_risk', '1945_disease', '204_peripheral neuropathy', '622_resonance', '1923_HbA1c', '2048_statistical analysis', '1954_hypoalbuminemia', '26_magnetic resonance imaging', '2351_incidence', '1912_ethnicity', '1104_amputations', '1595_first metatarsal', '1339_2013', '1519_hemoglobin', '1519_hemoglobin A1c', '2424_statistically significant', '1330_2008', '1143_institutional review board', '1252_Staten Island University', '1904_gender', '2247_MRI', '439_diabetic', '737_diabetic foot', '2556_MRI', '351_ulcers', '1434_amputation', '1407_413', '865_MRI', '2141_MRI', '252_risk factor', '1806_MRI', '439_diabetic foot', '101_foot', '2394_foot', '1657_Statistical analysis', '1584_hallux', '92_diabetic foot', '337_diabetic', '2577_amputation', '337_diabetic foot', '274_amputation', '321_foot', '35_resonance', '1549_3', '148_glycosylation', '337_diabetic foot ulcers', '537_disease', '1691_incidence', '1930_cardiovascular', '393_osteomyelitis', '297_trauma', '1613_amputation', '737_diabetic', '1601_metatarsal', '1980_body mass index', '498_amputations', '1252_Staten Island', '1277_Hospital', '1042_MRI', '1971_smoking', '108_Diabetes mellitus', '1369_great toe', '92_diabetic', '1762_MRI', '346_foot', '448_foot', '1985_mass', '1535_HbA1c', '1457_368', '1005_diabetic patients', '1427_hallux', '2007_antibiotic', '2265_mortality rates', '1236_413', '613_magnetic resonance imaging (MRI)'}

# %%
# following true class
true_json_path = constants.HOME + base_path + ds.split('/')[-2].replace('.json', '') + f'/{classes[0]}/{sample_id}.json'
true_systems_mentions = mc.getSystemMentions(true_json_path)
print(f'Following our true class, we get the following mentions: {true_systems_mentions}')
# Out:
# Following our true class, we get the following mentions: {'45_imaging', '2166_rate', '1990_index', '2385_diabetic', '2385_diabetic foot', '1380_hallux', '756_hypothesis', '1203_retrospective', '1203_retrospective cohort', '179_structures', '746_foot', '1980_body mass', '215_neuropathy', '1252_Staten Island University Hospital', '1375_toe', '2471_mortality rate', '194_resultant', '377_risk', '1930_cardiovascular disease', '1508_documented', '326_results', '372_high', '2471_mortality', '2301_MRI', '426_present', '1053_presurgical', '2196_statistical association', '1638_radiographic', '1710_reamputation', '1127_approval', '1388_amputation', '2088_significant', '844_obtaining', '2241_early', '2295_early', '892_planning', '1628_available', '1831_amputation', '108_Diabetes', '666_amputation', '2100_association', '252_risk', '1945_disease', '1669_analysis', '453_complications', '204_peripheral neuropathy', '622_resonance', '780_rate', '1014_patients', '1361_initial', '2033_results', '1923_HbA1c', '2189_find', '127_DM', '2048_statistical analysis', '1954_hypoalbuminemia', '1087_initial', '1297_tertiary', '26_magnetic resonance imaging', '808_associated', '2069_failed', '1266_University', '2228_obtaining', '2519_survival rate', '824_underutilization', '2275_rates', '26_magnetic', '2351_incidence', '605_initial', '1912_ethnicity', '268_pedal', '613_magnetic resonance imaging', '1104_amputations', '26_magnetic resonance', '1259_Island', '1985_mass index', '1224_analysis', '984_reamputation', '226_continues', '1691_incidence rates', '613_magnetic resonance', '1899_age', '788_reamputation', '2569_initial', '917_designed', '1519_hemoglobin', '1175_study', '0_Does', '1519_hemoglobin A1c', '1315_center', '2196_statistical', '1117_Following', '1252_Staten', '2153_reamputation', '18_initial', '1744_underwent', '647_prior', '1143_institutional review board', '311_insensate', '1551_months', '1217_cohort', '2528_rate', '632_imaging', '1489_history', '246_major', '579_determine', '1175_study design', '2545_undergoing', '2368_treatment', '1904_gender', '2247_MRI', '439_diabetic', '737_diabetic foot', '1143_institutional', '1530_A1c', '472_undergo', '2265_mortality', '613_magnetic', '1470_patients', '2556_MRI', '351_ulcers', '1434_amputation', '1731_patients', '521_course', '1798_initial', '960_association', '865_MRI', '492_pedal', '66_reamputation', '2141_MRI', '2424_statistically', '413_patients', '2313_associated', '2450_association', '550_purpose', '2133_initial', '252_risk factor', '1005_diabetic', '1806_MRI', '439_diabetic foot', '79_rates', '101_foot', '2208_association', '1157_review', '1461_eligible', '1065_planning', '681_associated', '1240_patients', '2481_rate', '1657_Statistical analysis', '997_rate', '2282_Obtaining', '2394_foot', '1500_DM', '1584_hallux', '53_decrease', '92_diabetic foot', '337_diabetic', '2509_increased', '337_diabetic foot', '274_amputation', '2577_amputation', '321_foot', '35_resonance', '1369_great', '880_presurgical', '699_decreased', '487_more pedal', '1411_patients', '148_glycosylation', '337_diabetic foot ulcers', '641_MRI', '566_study', '537_disease', '929_determine', '1579_ray', '2333_reamputation', '1095_forefoot', '2001_prior', '2060_analysis', '246_major risk', '1691_incidence', '1847_reamputation', '717_reamputation', '1164_board', '1930_cardiovascular', '5_obtaining', '1078_prior', '1489_history of DM', '393_osteomyelitis', '2048_statistical', '297_trauma', '870_useful', '1601_metatarsal', '737_diabetic', '857_initial', '1027_utilization', '1613_amputation', '907_study', '1980_body mass index', '498_amputations', '2489_demonstrated', '2519_survival', '1277_Hospital', '1042_MRI', '1971_smoking', '2346_rate', '1884_adjustment', '592_obtaining', '108_Diabetes mellitus', '1181_design', '709_rate', '1369_great toe', '2255_decreased', '92_diabetic', '2079_reveal', '2018_treatment', '1217_cohort analysis', '2120_obtaining', '1762_MRI', '1860_rate', '1754_initial', '257_factor', '346_foot', '448_foot', '1985_mas ...

# %%
# base truth
jl = JsonLoader(ds)
true_metions = list(jl.getDocumentsMentionsPairs().values())
for true_mention in true_metions:
    if hashStringSha256(true_mention['doc']) == sample_id:
        true_mentions = set(true_mention['mentions'])
    
    
print(f'True mentions (from nif): {true_mentions}')
# Out:
# True mentions (from nif): {'1499_DM', '2449_association', '1979_body mass index', '1970_smoking', '1052_presurgical', '755_hypothesis', '2254_decreased', '1564_initial', '1202_retrospective cohort analysis', '452_complications', '787_reamputation', '2132_initial', '126_DM', '1041_MRI', '1368_great toe (hallux) amputation', '2568_initial', '2576_amputation', '1911_ethnicity', '1753_initial', '2207_association', '843_obtaining', '1077_prior', '1239_patients', '2246_MRI', '509_during', '26_magnetic resonance imaging', '1094_forefoot amputations', '879_presurgical', '1650_data', '164_neurovascular structures', '251_risk factor', '1488_history', '2000_prior', '1612_amputation', '2264_mortality rates', '2470_mortality rate', '203_peripheral neuropathy', '371_high risk', '864_MRI', '1004_diabetic', '549_purpose', '2227_obtaining', '604_initial', '1690_incidence rates', '245_major', '565_study', '996_rate', '1174_study design', '612_magnetic resonance imaging', '1709_reamputation', '1761_MRI', '716_reamputation', '285_Repetitive', '18_initial', '2140_MRI', '2518_survival rate', '1824_first', '2195_statistical', '646_prior', '680_associated with', '1868_compared', '2345_rate incidence', '1730_patients', '959_association', '107_Diabetes mellitus', '536_disease', '2240_early', '520_course', '1637_radiographic', '1656_Statistical analysis', '1903_gender', '66_reamputation', '2152_reamputation', '1251_Staten Island University Hospital', '147_glycosylation', '2555_MRI', '1142_institutional review board', '79_rates', '2078_reveal', '1929_cardiovascular disease', '2281_Obtaining', '1809_prior', '1830_amputation', '2165_rate', '1013_patients', '438_diabetic foot', '2300_MRI', '412_patients', '267_pedal amputation', '53_decrease', '698_decreased', '92_diabetic foot', '1288_700-bed tertiary referral center', '1360_initial', '1064_planning', '2423_statistically significant', '1594_first metatarsal', '1805_MRI', '1426_hallux amputation', '2068_failed', '1086_initial', '983_reamputation', '336_diabetic foot ulcers', '2332_reamputation', '1550_months', '392_osteomyelitis', '708_rate', '1898_age', '1922_HbA1c', '665_amputation', '1410_patients', '2119_obtaining', '5_obtaining', '2312_associated with', '296_trauma', '2087_significant', '1469_patients', '779_rate', '2099_association', '310_insensate', '591_obtaining', '2367_treatment', '916_designed', '2294_early', '1846_reamputation', '640_MRI', '1026_utilization', '2032_results', '856_initial', '1460_eligible', '2384_diabetic foot', '1583_hallux', '1534_HbA1c', '1677_compared', '2006_antibiotic treatment', '2535_patients', '2559_prior', '325_results in', '2308_not', '1116_Following', '1518_hemoglobin A1c', '807_associated with', '1859_rate', '1883_adjustment', '1797_initial', '2047_statistical analysis', '736_diabetic foot', '491_pedal amputations', '1953_hypoalbuminemia', '906_study', '320_foot', '891_planning', '1572_first ray', '1126_approval', '2508_increased'}

# %%
print(f'f1 between pred and true class: {mc.calculate_f1(predicted_systems_mentions, true_systems_mentions)}')
print(f'f1 between a wrong and true class: {mc.calculate_f1(wrong_systems_mentions, true_systems_mentions)}')
print(f'f1 between pred class predictions and ground truth: {mc.calculate_f1(predicted_systems_mentions, true_mentions)}')
print(f'f1 between true class predictions and ground truth: {mc.calculate_f1(true_systems_mentions, true_mentions)}')
# Out:
# Intersection (TP): {'2385_diabetic', '2385_diabetic foot', '1380_hallux', '756_hypothesis', '1203_retrospective cohort', '746_foot', '1252_Staten Island University Hospital', '2471_mortality rate', '377_risk', '1930_cardiovascular disease', '2301_MRI', '1638_radiographic', '1388_amputation', '1831_amputation', '666_amputation', '252_risk', '1945_disease', '204_peripheral neuropathy', '622_resonance', '1923_HbA1c', '2048_statistical analysis', '1954_hypoalbuminemia', '26_magnetic resonance imaging', '2351_incidence', '1912_ethnicity', '1104_amputations', '1519_hemoglobin', '1519_hemoglobin A1c', '1143_institutional review board', '1904_gender', '2247_MRI', '439_diabetic', '737_diabetic foot', '2556_MRI', '351_ulcers', '1434_amputation', '865_MRI', '2141_MRI', '252_risk factor', '1806_MRI', '439_diabetic foot', '101_foot', '2394_foot', '1657_Statistical analysis', '1584_hallux', '92_diabetic foot', '337_diabetic', '2577_amputation', '337_diabetic foot', '274_amputation', '321_foot', '35_resonance', '148_glycosylation', '337_diabetic foot ulcers', '537_disease', '1691_incidence', '1930_cardiovascular', '393_osteomyelitis', '297_trauma', '1613_amputation', '737_diabetic', '1601_metatarsal', '1980_body mass index', '498_amputations', '1277_Hospital', '1042_MRI', '1971_smoking', '108_Diabetes mellitus', '1369_great toe', '92_diabetic', '1762_MRI', '346_foot', '448_foot', '1985_mass', '1535_HbA1c', '1427_hallux', '2007_antibiotic', '2265_mortality rates'}
# Intersection (FP): {'1252_Staten Island University', '1407_413', '1457_368', '2424_statistically significant', '1330_2008', '1252_Staten Island', '1549_3', '1005_diabetic patients', '1595_first metatarsal', '1339_2013', '1236_413', '613_magnetic resonance imaging (MRI)'}
# Intersection (FN): {'45_imaging', '2166_rate', '1990_index', '1203_retrospective', '179_structures', '1980_body mass', '215_neuropathy', '1375_toe', '194_resultant', '1508_documented', '326_results', '372_high', '2471_mortality', '426_present', '1053_presurgical', '2196_statistical association', '1710_reamputation', '1127_approval', '2088_significant', '2241_early', '844_obtaining', '2295_early', '892_planning', '1628_available', '2100_association', '108_Diabetes', '1669_analysis', '453_complications', '1014_patients', '780_rate', '1361_initial', '2033_results', '2189_find', '127_DM', '1087_initial', '1297_tertiary', '2069_failed', '808_associated', '2228_obtaining', '1266_University', '2519_survival rate', '824_underutilization', '2275_rates', '26_magnetic', '605_initial', '268_pedal', '613_magnetic resonance imaging', '26_magnetic resonance', '1259_Island', '1985_mass index', '1224_analysis', '984_reamputation', '226_continues', '1691_incidence rates', '613_magnetic resonance', '1899_age', '788_reamputation', '2569_initial', '917_designed', '1175_study', '0_Does', '1315_center', '2196_statistical', '1117_Following', '1252_Staten', '2153_reamputation', '18_initial', '1744_underwent', '647_prior', '311_insensate', '1551_months', '1217_cohort', '2528_rate', '632_imaging', '1489_history', '246_major', '579_determine', '1175_study design', '2545_undergoing', '2368_treatment', '1143_institutional', '1530_A1c', '472_undergo', '2265_mortality', '613_magnetic', '1470_patients', '1731_patients', '521_course', '1798_initial', '960_association', '492_pedal', '66_reamputation', '2424_statistically', '413_patients', '2313_associated', '2450_association', '550_purpose', '2133_initial', '1005_diabetic', '79_rates', '2208_association', '1157_review', '1461_eligible', '1065_planning', '681_associated', '1240_patients', '2481_rate', '2282_Obtaining', '997_rate', '1500_DM', '53_decrease', '2509_increased', '1369_great', '880_presurgical', '699_decreased', '487_more pedal', '1411_patients', '641_MRI', '566_study', '1579_ray', '929_determine', '2333_reamputation', '1095_forefoot', '2001_prior', '2060_analysis', '246_major risk', '1847_reamputation', '717_reamputation', '1164_board', '5_obtaining', '1078_prior', '1489_history of DM', '2048_statistical', '870_useful', '2519_survival', '857_initial', '1027_utilization', '2489_demonstrated', '907_study', '2346_rate', '1884_adjustment', '592_obtaining', '1181_design', '2255_decreased', '709_rate', '2079_reveal', '2018_treatment', '1217_cohort analysis', '2120_obtaining', '1860_rate', '1754_initial', '257_factor', '1657_Statistical', '1869_compared', '204_peripheral', '2536_patients', '385_develop', '1306_referral', '1788_obtain', '1810_prior', '2560_prior', '1980_body', '1678_compared', '1565_initial', '1651_data', '1701_rates', '1348_underwent', '165_neurovascular', '2438_significant'}
# f1 between pred and true class: 0.4629080118694362
# Intersection (TP): {'127_DM', '641_MRI', '1806_MRI', '865_MRI', '2141_MRI', '2247_MRI', '2301_MRI', '1042_MRI', '1530_A1c', '1762_MRI', '1252_Staten Island University Hospital', '2556_MRI', '1500_DM'}
# Intersection (FP): set()
# Intersection (FN): {'45_imaging', '2166_rate', '1990_index', '2385_diabetic', '2385_diabetic foot', '1380_hallux', '756_hypothesis', '1203_retrospective', '1203_retrospective cohort', '179_structures', '746_foot', '1980_body mass', '215_neuropathy', '1375_toe', '2471_mortality rate', '194_resultant', '377_risk', '1930_cardiovascular disease', '1508_documented', '326_results', '372_high', '2471_mortality', '426_present', '1053_presurgical', '2196_statistical association', '1638_radiographic', '1710_reamputation', '1127_approval', '1388_amputation', '2088_significant', '844_obtaining', '2241_early', '2295_early', '892_planning', '1628_available', '1831_amputation', '108_Diabetes', '666_amputation', '2100_association', '252_risk', '1945_disease', '1669_analysis', '453_complications', '204_peripheral neuropathy', '622_resonance', '780_rate', '1014_patients', '1361_initial', '2033_results', '1923_HbA1c', '2189_find', '2048_statistical analysis', '1954_hypoalbuminemia', '1087_initial', '1297_tertiary', '26_magnetic resonance imaging', '808_associated', '2069_failed', '1266_University', '2228_obtaining', '2519_survival rate', '824_underutilization', '2275_rates', '26_magnetic', '2351_incidence', '605_initial', '1912_ethnicity', '268_pedal', '613_magnetic resonance imaging', '1104_amputations', '26_magnetic resonance', '1259_Island', '1985_mass index', '1224_analysis', '984_reamputation', '226_continues', '1691_incidence rates', '613_magnetic resonance', '1899_age', '788_reamputation', '2569_initial', '917_designed', '1519_hemoglobin', '1175_study', '0_Does', '1519_hemoglobin A1c', '1315_center', '2196_statistical', '1117_Following', '1252_Staten', '2153_reamputation', '18_initial', '1744_underwent', '647_prior', '1143_institutional review board', '311_insensate', '1551_months', '1217_cohort', '2528_rate', '632_imaging', '1489_history', '246_major', '579_determine', '1175_study design', '2545_undergoing', '2368_treatment', '1904_gender', '439_diabetic', '737_diabetic foot', '1143_institutional', '472_undergo', '2265_mortality', '613_magnetic', '1470_patients', '351_ulcers', '1434_amputation', '1731_patients', '521_course', '1798_initial', '960_association', '492_pedal', '66_reamputation', '2424_statistically', '413_patients', '2313_associated', '2450_association', '550_purpose', '2133_initial', '252_risk factor', '1005_diabetic', '439_diabetic foot', '79_rates', '101_foot', '2208_association', '1157_review', '1461_eligible', '1065_planning', '681_associated', '1240_patients', '2481_rate', '1657_Statistical analysis', '997_rate', '2282_Obtaining', '2394_foot', '1584_hallux', '53_decrease', '92_diabetic foot', '337_diabetic', '2509_increased', '337_diabetic foot', '274_amputation', '2577_amputation', '321_foot', '35_resonance', '1369_great', '880_presurgical', '699_decreased', '487_more pedal', '1411_patients', '148_glycosylation', '337_diabetic foot ulcers', '566_study', '537_disease', '929_determine', '1579_ray', '2333_reamputation', '1095_forefoot', '2001_prior', '2060_analysis', '246_major risk', '1691_incidence', '1847_reamputation', '717_reamputation', '1164_board', '1930_cardiovascular', '5_obtaining', '1078_prior', '1489_history of DM', '393_osteomyelitis', '2048_statistical', '297_trauma', '870_useful', '1601_metatarsal', '737_diabetic', '857_initial', '1027_utilization', '1613_amputation', '907_study', '1980_body mass index', '498_amputations', '2489_demonstrated', '2519_survival', '1277_Hospital', '1971_smoking', '2346_rate', '1884_adjustment', '592_obtaining', '108_Diabetes mellitus', '1181_design', '709_rate', '1369_great toe', '2255_decreased', '92_diabetic', '2079_reveal', '2018_treatment', '1217_cohort analysis', '2120_obtaining', '1860_rate', '1754_initial', '257_factor', '346_foot', '448_foot', '1985_mass', '1535_HbA1c', '1657_Statistical', '1869_compared', '204_peripheral', '2536_patients', '385_develop', '1306_referral', '1788_obtain', '1810_prior', '2560_prior', '1980_body', '1427_hallux', '1678_compared', '2007_ant ...
# f1 between a wrong and true class: 0.1
# Intersection (TP): {'92_diabetic foot', '26_magnetic resonance imaging'}
# Intersection (FP): {'2385_diabetic', '2385_diabetic foot', '1380_hallux', '756_hypothesis', '1203_retrospective cohort', '746_foot', '1252_Staten Island University Hospital', '2471_mortality rate', '377_risk', '1930_cardiovascular disease', '2301_MRI', '1638_radiographic', '1388_amputation', '1831_amputation', '666_amputation', '252_risk', '1945_disease', '204_peripheral neuropathy', '622_resonance', '1923_HbA1c', '2048_statistical analysis', '1954_hypoalbuminemia', '2351_incidence', '1912_ethnicity', '1104_amputations', '1595_first metatarsal', '1339_2013', '1519_hemoglobin', '1519_hemoglobin A1c', '2424_statistically significant', '1330_2008', '1143_institutional review board', '1252_Staten Island University', '1904_gender', '2247_MRI', '439_diabetic', '737_diabetic foot', '2556_MRI', '351_ulcers', '1434_amputation', '1407_413', '865_MRI', '2141_MRI', '252_risk factor', '1806_MRI', '439_diabetic foot', '101_foot', '2394_foot', '1657_Statistical analysis', '1584_hallux', '337_diabetic', '2577_amputation', '337_diabetic foot', '274_amputation', '321_foot', '35_resonance', '1549_3', '148_glycosylation', '337_diabetic foot ulcers', '537_disease', '1691_incidence', '1930_cardiovascular', '393_osteomyelitis', '297_trauma', '1613_amputation', '737_diabetic', '1601_metatarsal', '1980_body mass index', '498_amputations', '1252_Staten Island', '1277_Hospital', '1042_MRI', '1971_smoking', '108_Diabetes mellitus', '1369_great toe', '92_diabetic', '1762_MRI', '346_foot', '448_foot', '1985_mass', '1535_HbA1c', '1457_368', '1005_diabetic patients', '1427_hallux', '2007_antibiotic', '2265_mortality rates', '1236_413', '613_magnetic resonance imaging (MRI)'}
# Intersection (FN): {'1499_DM', '2449_association', '1979_body mass index', '1970_smoking', '1052_presurgical', '755_hypothesis', '2254_decreased', '1564_initial', '1202_retrospective cohort analysis', '452_complications', '787_reamputation', '2132_initial', '126_DM', '1041_MRI', '1368_great toe (hallux) amputation', '2568_initial', '2576_amputation', '1911_ethnicity', '1753_initial', '2207_association', '843_obtaining', '1077_prior', '1239_patients', '2246_MRI', '509_during', '1094_forefoot amputations', '879_presurgical', '1650_data', '164_neurovascular structures', '1488_history', '2000_prior', '251_risk factor', '1612_amputation', '2264_mortality rates', '2470_mortality rate', '203_peripheral neuropathy', '371_high risk', '864_MRI', '1004_diabetic', '549_purpose', '2227_obtaining', '604_initial', '1690_incidence rates', '245_major', '565_study', '996_rate', '1174_study design', '612_magnetic resonance imaging', '1709_reamputation', '1761_MRI', '716_reamputation', '285_Repetitive', '18_initial', '2140_MRI', '2518_survival rate', '1824_first', '2195_statistical', '646_prior', '680_associated with', '1868_compared', '2345_rate incidence', '1730_patients', '959_association', '107_Diabetes mellitus', '536_disease', '2240_early', '520_course', '1637_radiographic', '1656_Statistical analysis', '1903_gender', '66_reamputation', '2152_reamputation', '1251_Staten Island University Hospital', '147_glycosylation', '2555_MRI', '1142_institutional review board', '79_rates', '2078_reveal', '1929_cardiovascular disease', '2281_Obtaining', '1809_prior', '1830_amputation', '2165_rate', '1013_patients', '438_diabetic foot', '2300_MRI', '412_patients', '267_pedal amputation', '53_decrease', '698_decreased', '1288_700-bed tertiary referral center', '1360_initial', '1064_planning', '2423_statistically significant', '1594_first metatarsal', '1805_MRI', '1426_hallux amputation', '2068_failed', '1086_initial', '983_reamputation', '336_diabetic foot ulcers', '2332_reamputation', '1550_months', '392_osteomyelitis', '708_rate', '1898_age', '1922_HbA1c', '665_amputation', '1410_patients', '2119_obtaining', '5_obtaining', '2312_associated with', '296_trauma', '2087_significant', '1469_patients', '779_rate', '2099_association', '310_insensate', '591_obtaining', '2367_treatment', '916_designed', '2294_early', '1846_reamputation', '640_MRI', '1026_utilization', '2032_results', '856_initial', '1460_eligible', '2384_diabetic foot', '1583_hallux', '1534_HbA1c', '1677_compared', '2006_antibiotic treatment', '2535_patients', '2559_prior', '325_results in', '2308_not', '1116_Following', '1518_hemoglobin A1c', '807_associated with', '1859_rate', '1883_adjustment', '1797_initial', '2047_statistical analysis', '736_diabetic foot', '491_pedal amputations', '1953_hypoalbuminemia', '906_study', '320_foot', '891_planning', '1572_first ray', '1126_approval', '2508_increased'}
# f1 between pred class predictions and ground truth: 0.016326530612244896
# Intersection (TP): {'53_decrease', '92_diabetic foot', '79_rates', '5_obtaining', '26_magnetic resonance imaging', '66_reamputation', '18_initial'}
# Intersection (FP): {'45_imaging', '2166_rate', '1990_index', '2385_diabetic', '2385_diabetic foot', '1380_hallux', '756_hypothesis', '1203_retrospective', '1203_retrospective cohort', '179_structures', '746_foot', '1980_body mass', '1252_Staten Island University Hospital', '215_neuropathy', '2471_mortality rate', '1375_toe', '194_resultant', '377_risk', '1930_cardiovascular disease', '1508_documented', '326_results', '372_high', '2471_mortality', '2301_MRI', '426_present', '1053_presurgical', '2196_statistical association', '1638_radiographic', '1710_reamputation', '1127_approval', '1388_amputation', '2088_significant', '844_obtaining', '2241_early', '2295_early', '892_planning', '1628_available', '1831_amputation', '108_Diabetes', '666_amputation', '2100_association', '252_risk', '1945_disease', '1669_analysis', '453_complications', '204_peripheral neuropathy', '622_resonance', '780_rate', '1014_patients', '1361_initial', '2033_results', '1923_HbA1c', '2189_find', '127_DM', '2048_statistical analysis', '1954_hypoalbuminemia', '1087_initial', '1297_tertiary', '2069_failed', '808_associated', '2228_obtaining', '1266_University', '2519_survival rate', '824_underutilization', '2275_rates', '26_magnetic', '2351_incidence', '605_initial', '1912_ethnicity', '268_pedal', '613_magnetic resonance imaging', '1104_amputations', '26_magnetic resonance', '1259_Island', '1985_mass index', '1224_analysis', '984_reamputation', '226_continues', '1691_incidence rates', '613_magnetic resonance', '1899_age', '788_reamputation', '2569_initial', '917_designed', '1519_hemoglobin', '1175_study', '0_Does', '1519_hemoglobin A1c', '1315_center', '2196_statistical', '1117_Following', '1252_Staten', '2153_reamputation', '1744_underwent', '647_prior', '1143_institutional review board', '311_insensate', '1551_months', '1217_cohort', '2528_rate', '632_imaging', '1489_history', '246_major', '579_determine', '1175_study design', '2545_undergoing', '2368_treatment', '1904_gender', '2247_MRI', '439_diabetic', '737_diabetic foot', '1143_institutional', '1530_A1c', '472_undergo', '2265_mortality', '613_magnetic', '1470_patients', '2556_MRI', '351_ulcers', '1434_amputation', '1731_patients', '521_course', '1798_initial', '960_association', '865_MRI', '492_pedal', '2141_MRI', '2424_statistically', '413_patients', '2313_associated', '2450_association', '550_purpose', '2133_initial', '252_risk factor', '1005_diabetic', '1806_MRI', '439_diabetic foot', '101_foot', '2208_association', '1157_review', '1461_eligible', '1065_planning', '681_associated', '1240_patients', '2481_rate', '1657_Statistical analysis', '997_rate', '2282_Obtaining', '2394_foot', '1500_DM', '1584_hallux', '337_diabetic', '2509_increased', '337_diabetic foot', '274_amputation', '2577_amputation', '321_foot', '35_resonance', '1369_great', '880_presurgical', '699_decreased', '487_more pedal', '1411_patients', '148_glycosylation', '337_diabetic foot ulcers', '641_MRI', '566_study', '537_disease', '929_determine', '1579_ray', '2333_reamputation', '1095_forefoot', '2001_prior', '2060_analysis', '246_major risk', '1691_incidence', '1847_reamputation', '717_reamputation', '1164_board', '1930_cardiovascular', '1078_prior', '1489_history of DM', '393_osteomyelitis', '2048_statistical', '297_trauma', '870_useful', '1601_metatarsal', '737_diabetic', '857_initial', '1027_utilization', '1613_amputation', '907_study', '1980_body mass index', '498_amputations', '2489_demonstrated', '2519_survival', '1277_Hospital', '1042_MRI', '1971_smoking', '2346_rate', '1884_adjustment', '592_obtaining', '108_Diabetes mellitus', '1181_design', '709_rate', '1369_great toe', '2255_decreased', '92_diabetic', '2079_reveal', '2018_treatment', '1217_cohort analysis', '2120_obtaining', '1762_MRI', '1860_rate', '1754_initial', '257_factor', '346_foot', '448_foot', '1985_mass', '1535_HbA1c', '1657_Statistical', '1869_compared', '204_peripheral', '2536_patients', '385_develop', '1306_referral', '1788_obtain', '1810_prior', '2560_prior', ' ...
# Intersection (FN): {'1499_DM', '2449_association', '1979_body mass index', '1970_smoking', '1052_presurgical', '755_hypothesis', '2254_decreased', '1564_initial', '1202_retrospective cohort analysis', '452_complications', '787_reamputation', '2132_initial', '126_DM', '1041_MRI', '1368_great toe (hallux) amputation', '2568_initial', '2576_amputation', '1911_ethnicity', '1753_initial', '2207_association', '843_obtaining', '1077_prior', '1239_patients', '2246_MRI', '509_during', '1094_forefoot amputations', '879_presurgical', '1650_data', '164_neurovascular structures', '1488_history', '2000_prior', '251_risk factor', '1612_amputation', '2264_mortality rates', '2470_mortality rate', '203_peripheral neuropathy', '371_high risk', '864_MRI', '1004_diabetic', '549_purpose', '2227_obtaining', '604_initial', '1690_incidence rates', '245_major', '565_study', '996_rate', '1174_study design', '612_magnetic resonance imaging', '1709_reamputation', '1761_MRI', '716_reamputation', '285_Repetitive', '2140_MRI', '2518_survival rate', '1824_first', '2195_statistical', '646_prior', '680_associated with', '1868_compared', '2345_rate incidence', '1730_patients', '959_association', '107_Diabetes mellitus', '536_disease', '2240_early', '520_course', '1637_radiographic', '1656_Statistical analysis', '1903_gender', '2152_reamputation', '1251_Staten Island University Hospital', '147_glycosylation', '2555_MRI', '1142_institutional review board', '2078_reveal', '1929_cardiovascular disease', '2281_Obtaining', '1809_prior', '1830_amputation', '2165_rate', '1013_patients', '438_diabetic foot', '2300_MRI', '412_patients', '267_pedal amputation', '698_decreased', '1288_700-bed tertiary referral center', '1360_initial', '1064_planning', '2423_statistically significant', '1594_first metatarsal', '1805_MRI', '1426_hallux amputation', '2068_failed', '1086_initial', '983_reamputation', '336_diabetic foot ulcers', '2332_reamputation', '1550_months', '392_osteomyelitis', '708_rate', '1898_age', '1922_HbA1c', '665_amputation', '1410_patients', '2119_obtaining', '2312_associated with', '296_trauma', '2087_significant', '1469_patients', '779_rate', '2099_association', '310_insensate', '591_obtaining', '2367_treatment', '916_designed', '2294_early', '1846_reamputation', '640_MRI', '1026_utilization', '2032_results', '856_initial', '1460_eligible', '2384_diabetic foot', '1583_hallux', '1534_HbA1c', '1677_compared', '2006_antibiotic treatment', '2535_patients', '2559_prior', '325_results in', '2308_not', '1116_Following', '1518_hemoglobin A1c', '807_associated with', '1859_rate', '1883_adjustment', '1797_initial', '2047_statistical analysis', '736_diabetic foot', '491_pedal amputations', '1953_hypoalbuminemia', '906_study', '320_foot', '891_planning', '1572_first ray', '1126_approval', '2508_increased'}
# f1 between true class predictions and ground truth: 0.03482587064676617

# %%
#bert topic 
#dummy classifier
#PCA
#reduce number of classes
#RF topic id + emb
